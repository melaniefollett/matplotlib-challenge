# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_data_df = pd.read_csv(mouse_drug_data_to_load)
trial_data_df = pd.read_csv(clinical_trial_data_to_load)

# Combine the data into a single dataset
combined_data_df = pd.merge(mouse_data_df, trial_data_df, how='inner', on='Mouse ID')

# Display the data table for preview
combined_data_df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Group data by Drug and Timepoint
drug_time_groups = combined_data_df.groupby(["Drug", "Timepoint"])

# Store the Mean Tumor Volume Data
mean_tumor_vol = drug_time_groups["Tumor Volume (mm3)"].mean()

# Convert to DataFrame
tumor_mean_df = pd.DataFrame(mean_tumor_vol).reset_index(["Drug", "Timepoint"])

# Preview DataFrame
tumor_mean_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# ..        ...        ...                 ...
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0           45.000000
# 1   Capomulin          5           44.266086
# 2   Capomulin         10           43.084291
# 3   Capomulin         15           42.064317
# 4   Capomulin         20           40.716325
# 5   Capomulin         25           39.939528
# 6   Capomulin         30           38.769339
# 7   Capomulin         35           37.816839
# 8   Capomulin         40           36.958001
# 9   Capomulin         45           36.236114
# 10   Ceftamin          0           45.000000
# 11   Ceftamin          5           46.503051
# 12   Ceftamin         10           48.285125
# 13   Ceftamin         15           50.094055
# 14   Ceftamin         20           52.157049
# 15   Ceftamin         25           54.287674
# 16   Ceftamin         30           56.769517
# 17   Ceftamin         35           58.827548
# 18   Ceftamin         40           61.467895
# 19   Ceftamin         45           64.132421
# 20  Infubinol          0           45.000000
# 21  Infubinol          5           47.062001
# 22  Infubinol         10           49.403909
# 23  Infubinol         15           51.296397
# 24  Infubinol         20           53.197691
# 25  Infubinol         25           55.715252
# 26  Infubinol         30           58.299397
# 27  Infubinol         35           60.742461
# 28  Infubinol         40           63.162824
# 29  Infubinol         45           65.755562
# ..        ...        ...                 ...
# 70   Ramicane          0           45.000000
# 71   Ramicane          5           43.944859
# 72   Ramicane         10           42.531957
# 73   Ramicane         15           41.495061
# 74   Ramicane         20           40.238325
# 75   Ramicane         25           38.974300
# 76   Ramicane         30           38.703137
# 77   Ramicane         35           37.451996
# 78   Ramicane         40           36.574081
# 79   Ramicane         45           34.955595
# 80   Stelasyn          0           45.000000
# 81   Stelasyn          5           47.527452
# 82   Stelasyn         10           49.463844
# 83   Stelasyn         15           51.529409
# 84   Stelasyn         20           54.067395
# 85   Stelasyn         25           56.166123
# 86   Stelasyn         30           59.826738
# 87   Stelasyn         35           62.440699
# 88   Stelasyn         40           65.356386
# 89   Stelasyn         45           68.438310
# 90  Zoniferol          0           45.000000
# 91  Zoniferol          5           46.851818
# 92  Zoniferol         10           48.689881
# 93  Zoniferol         15           50.779059
# 94  Zoniferol         20           53.170334
# 95  Zoniferol         25           55.432935
# 96  Zoniferol         30           57.713531
# 97  Zoniferol         35           60.089372
# 98  Zoniferol         40           62.916692
# 99  Zoniferol         45           65.960888
#
# [100 rows x 3 columns]

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
sem_tumor_vol = drug_time_groups["Tumor Volume (mm3)"].sem()

# Convert to DataFrame
tumor_sem_df = pd.DataFrame(sem_tumor_vol).reset_index(["Drug", "Timepoint"])

# Preview DataFrame
tumor_sem_df
# Out:
#          Drug  Timepoint  Tumor Volume (mm3)
# 0   Capomulin          0            0.000000
# 1   Capomulin          5            0.448593
# 2   Capomulin         10            0.702684
# 3   Capomulin         15            0.838617
# 4   Capomulin         20            0.909731
# ..        ...        ...                 ...
# 95  Zoniferol         25            0.602513
# 96  Zoniferol         30            0.800043
# 97  Zoniferol         35            0.881426
# 98  Zoniferol         40            0.998515
# 99  Zoniferol         45            1.003576
#
# [100 rows x 3 columns]

# %%
# Out:
#         Drug  Timepoint  Tumor Volume (mm3)
# 0  Capomulin          0            0.000000
# 1  Capomulin          5            0.448593
# 2  Capomulin         10            0.702684
# 3  Capomulin         15            0.838617
# 4  Capomulin         20            0.909731

# %%
# Minor Data Munging to Re-Format the Mean Data Frame
reformat_tumor_mean_df = tumor_mean_df.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

# Preview that Reformatting worked
reformat_tumor_mean_df
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
# 25         39.939528  54.287674  55.715252  57.678982  56.731968  57.482574
# 30         38.769339  56.769517  58.299397  60.994507  59.559509  59.809063
# 35         37.816839  58.827548  60.742461  63.371686  62.685087  62.420615
# 40         36.958001  61.467895  63.162824  66.068580  65.600754  65.052675
# 45         36.236114  64.132421  65.755562  70.662958  69.265506  68.084082
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334
# 25         55.504138  38.974300  56.166123  55.432935
# 30         58.196374  38.703137  59.826738  57.713531
# 35         60.350199  37.451996  62.440699  60.089372
# 40         63.045537  36.574081  65.356386  62.916692
# 45         66.258529  34.955595  68.438310  65.960888

# %%
# Minor Data Munging to Re-Format the SEM Data Frame
reformat_tumor_sem_df = tumor_sem_df.pivot(index="Timepoint", columns="Drug", values="Tumor Volume (mm3)")

# Preview that Reformatting worked
reformat_tumor_sem_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.448593  0.164505   0.235102  0.264819  0.202385  0.218091
# 10          0.702684  0.236144   0.282346  0.357421  0.319415  0.402064
# 15          0.838617  0.332053   0.357705  0.580268  0.444378  0.614461
# 20          0.909731  0.359482   0.476210  0.726484  0.595260  0.839609
# 25          0.881642  0.439356   0.550315  0.755413  0.813706  1.034872
# 30          0.934460  0.490620   0.631061  0.934121  0.975496  1.218231
# 35          1.052241  0.692248   0.984155  1.127867  1.013769  1.287481
# 40          1.223608  0.708505   1.055220  1.158449  1.118567  1.370634
# 45          1.223977  0.902358   1.144427  1.453186  1.416363  1.351726
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.231708  0.482955  0.239862   0.188950
# 10         0.376195  0.720225  0.433678   0.263949
# 15         0.466109  0.770432  0.493261   0.370544
# 20         0.555181  0.786199  0.621889   0.533182
# 25         0.577401  0.746991  0.741922   0.602513
# 30         0.746045  0.864906  0.899548   0.800043
# 35         1.084929  0.967433  1.003186   0.881426
# 40         1.564779  1.128445  1.410435   0.998515
# 45         1.888586  1.226805  1.576556   1.003576

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

x_axis = reformat_tumor_mean_df.index.values
num_drug_groups = len(reformat_tumor_mean_df.columns)

fig, ax = plt.subplots(figsize=(12, 8))
for i in range(num_drug_groups):
    ax.errorbar(x_axis, reformat_tumor_mean_df.iloc[:, i], yerr=reformat_tumor_sem_df.iloc[:, i], fmt="o", Label=reformat_tumor_mean_df.columns[i])
ax.set_xlabel("Timepoint (days)")
ax.set_ylabel("Tumor Volume (mm3)")
ax.set_title("Change in Tumor Volume (mm3) Over Time for Different Drug Groups")
ax.legend(loc='best', frameon=True)
plt.show()

# Save the Figure
plt.savefig('../Pymaceuticals/tumor_vol_time.png')

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 
mean_met_sites = drug_time_groups["Metastatic Sites"].mean()

# Convert to DataFrame
metsites_mean_df = pd.DataFrame(mean_met_sites).reset_index(["Drug", "Timepoint"])

# Preview DataFrame
metsites_mean_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.160000
# 2   Capomulin         10          0.320000
# 3   Capomulin         15          0.375000
# 4   Capomulin         20          0.652174
# ..        ...        ...               ...
# 95  Zoniferol         25          1.687500
# 96  Zoniferol         30          1.933333
# 97  Zoniferol         35          2.285714
# 98  Zoniferol         40          2.785714
# 99  Zoniferol         45          3.071429
#
# [100 rows x 3 columns]

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
sem_met_sites = drug_time_groups["Metastatic Sites"].sem()

# Convert to DataFrame
metsites_sem_df = pd.DataFrame(sem_met_sites).reset_index(["Drug", "Timepoint"])

# Preview DataFrame
metsites_sem_df
# Out:
#          Drug  Timepoint  Metastatic Sites
# 0   Capomulin          0          0.000000
# 1   Capomulin          5          0.074833
# 2   Capomulin         10          0.125433
# 3   Capomulin         15          0.132048
# 4   Capomulin         20          0.161621
# ..        ...        ...               ...
# 95  Zoniferol         25          0.236621
# 96  Zoniferol         30          0.248168
# 97  Zoniferol         35          0.285714
# 98  Zoniferol         40          0.299791
# 99  Zoniferol         45          0.286400
#
# [100 rows x 3 columns]

# %%
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.074833
#           10                 0.125433
#           15                 0.132048
#           20                 0.161621

# %%
# Minor Data Munging to Re-Format the Data Frames
reformat_metsites_mean_df = metsites_mean_df.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# Preview that Reformatting worked
reformat_metsites_mean_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.160000  0.380952   0.280000  0.304348  0.260870  0.375000
# 10          0.320000  0.600000   0.666667  0.590909  0.523810  0.833333
# 15          0.375000  0.789474   0.904762  0.842105  0.857143  1.250000
# 20          0.652174  1.111111   1.050000  1.210526  1.150000  1.526316
# 25          0.818182  1.500000   1.277778  1.631579  1.500000  1.941176
# 30          1.090909  1.937500   1.588235  2.055556  2.066667  2.266667
# 35          1.181818  2.071429   1.666667  2.294118  2.266667  2.642857
# 40          1.380952  2.357143   2.100000  2.733333  2.466667  3.166667
# 45          1.476190  2.692308   2.111111  3.363636  2.538462  3.272727
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.320000  0.120000  0.240000   0.166667
# 10         0.565217  0.250000  0.478261   0.500000
# 15         0.764706  0.333333  0.782609   0.809524
# 20         1.000000  0.347826  0.952381   1.294118
# 25         1.357143  0.652174  1.157895   1.687500
# 30         1.615385  0.782609  1.388889   1.933333
# 35         2.300000  0.952381  1.562500   2.285714
# 40         2.777778  1.100000  1.583333   2.785714
# 45         2.571429  1.250000  1.727273   3.071429

# %%
# Minor Data Munging to Re-Format the SEM Data Frame
reformat_metsites_sem_df = metsites_sem_df.pivot(index="Timepoint", columns="Drug", values="Metastatic Sites")

# Preview that Reformatting worked
reformat_metsites_sem_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol   Placebo  \
# Timepoint
# 0           0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5           0.074833  0.108588   0.091652  0.098100  0.093618  0.100947
# 10          0.125433  0.152177   0.159364  0.142018  0.163577  0.115261
# 15          0.132048  0.180625   0.194015  0.191381  0.158651  0.190221
# 20          0.161621  0.241034   0.234801  0.236680  0.181731  0.234064
# 25          0.181818  0.258831   0.265753  0.288275  0.185240  0.263888
# 30          0.172944  0.249479   0.227823  0.347467  0.266667  0.300264
# 35          0.169496  0.266526   0.224733  0.361418  0.330464  0.341412
# 40          0.175610  0.289128   0.314466  0.315725  0.321702  0.297294
# 45          0.202591  0.286101   0.309320  0.278722  0.351104  0.304240
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000   0.000000
# 5          0.095219  0.066332  0.087178   0.077709
# 10         0.105690  0.090289  0.123672   0.109109
# 15         0.136377  0.115261  0.153439   0.111677
# 20         0.171499  0.119430  0.200905   0.166378
# 25         0.199095  0.119430  0.219824   0.236621
# 30         0.266469  0.139968  0.230641   0.248168
# 35         0.366667  0.145997  0.240983   0.285714
# 40         0.433903  0.160591  0.312815   0.299791
# 45         0.428571  0.190221  0.359062   0.286400

# %%
# Out:
# Drug       Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol    Placebo  \
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000  45.000000
# 5          44.266086  46.503051  47.062001  47.389175  46.796098  47.125589
# 10         43.084291  48.285125  49.403909  49.582269  48.694210  49.423329
# 15         42.064317  50.094055  51.296397  52.399974  50.933018  51.359742
# 20         40.716325  52.157049  53.197691  54.920935  53.644087  54.364417
#
# Drug        Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000
# 5          47.248967  43.944859  47.527452  46.851818
# 10         49.101541  42.531957  49.463844  48.689881
# 15         51.067318  41.495061  51.529409  50.779059
# 20         53.346737  40.238325  54.067395  53.170334

# %%
# Generate the Plot (with Error Bars)

x_axis = reformat_metsites_mean_df.index.values
num_drug_groups = len(reformat_tumor_mean_df.columns)

fig, ax = plt.subplots(figsize=(12, 8))
for i in range(num_drug_groups):
    ax.errorbar(x_axis, reformat_metsites_mean_df.iloc[:, i], yerr=reformat_metsites_sem_df.iloc[:, i], fmt="o", Label=reformat_metsites_mean_df.columns[i])
ax.set_xlabel("Timepoint (days)")
ax.set_ylabel("Number of Metastatic Sites")
ax.set_title("Change in Number of Metastatic Sites Over Time for Different Drug Groups")
ax.legend(loc='best', frameon=True)
plt.show()

# Save the Figure
plt.savefig('../Pymaceuticals/met_sites_time.png')

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)
num_mice = drug_time_groups["Mouse ID"].nunique()

# Convert to DataFrame
mice_surv_df = pd.DataFrame(num_mice).reset_index(["Drug", "Timepoint"]).rename(columns={"Mouse ID":"Mouse Count"})

# Preview DataFrame
mice_surv_df
# Out:
#          Drug  Timepoint  Mouse Count
# 0   Capomulin          0           25
# 1   Capomulin          5           25
# 2   Capomulin         10           25
# 3   Capomulin         15           24
# 4   Capomulin         20           23
# ..        ...        ...          ...
# 95  Zoniferol         25           16
# 96  Zoniferol         30           15
# 97  Zoniferol         35           14
# 98  Zoniferol         40           14
# 99  Zoniferol         45           14
#
# [100 rows x 3 columns]

# %%
# Out:
#         Drug  Timepoint  Mouse Count
# 0  Capomulin          0           25
# 1  Capomulin          5           25
# 2  Capomulin         10           25
# 3  Capomulin         15           24
# 4  Capomulin         20           23

# %%
# Minor Data Munging to Re-Format the Data Frames
reformat_mice_surv_df = mice_surv_df.pivot(index="Timepoint", columns="Drug", values="Mouse Count")

# Preview the Data Frame
reformat_mice_surv_df
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
# 25                22        18         18        19        18       17
# 30                22        16         17        18        15       15
# 35                22        14         12        17        15       14
# 40                21        14         10        15        15       12
# 45                21        13          9        11        13       11
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                25        25        25         25
# 5                24        25        24         24
# 10               22        24        22         22
# 15               16        24        22         21
# 20               16        23        20         17
# 25               14        23        19         16
# 30               13        23        18         15
# 35               10        21        16         14
# 40                9        20        12         14
# 45                7        20        11         14

# %%
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Generate the Plot (Accounting for percentages)
x_axis = reformat_mice_surv_df.index.values
num_drug_groups = len(reformat_mice_surv_df.columns)

fig, ax = plt.subplots(figsize=(12, 8))
for i in range(num_drug_groups):
    ax.errorbar(x_axis, reformat_mice_surv_df.iloc[:, i], fmt="o", Label=reformat_metsites_mean_df.columns[i])
ax.set_xlabel("Timepoint (days)")
ax.set_ylabel("Number of Surviving Mice")
ax.set_title("Change in Number of Surviving Mice Over Time for Different Drug Groups")
ax.legend(loc='best', frameon=True)
plt.show()

# Save the Figure
plt.savefig('../Pymaceuticals/mice_surv_time.png')

# %%
#I know it asked for a scatterplot, but I thought adding lines to the groups would make the data more readable.
#So I included both versions, hope that's ok!

# Generate the Plot (Accounting for percentages)
x_axis = reformat_mice_surv_df.index.values
num_drug_groups = len(reformat_mice_surv_df.columns)

fig, ax = plt.subplots(figsize=(12, 8))
for i in range(num_drug_groups):
    ax.errorbar(x_axis, reformat_mice_surv_df.iloc[:, i], fmt="o", linestyle='-', Label=reformat_metsites_mean_df.columns[i])
ax.set_xlabel("Timepoint (days)")
ax.set_ylabel("Number of Surviving Mice")
ax.set_title("Change in Number of Surviving Mice Over Time for Different Drug Groups")
ax.legend(loc='best', frameon=True)
plt.show()

# Save the Figure
plt.savefig('../Pymaceuticals/mice_surv_time_lines.png')

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug
drug_groups = combined_data_df.groupby(["Drug"])


tumor_start = drug_groups["Tumor Volume (mm3)"].first()
tumor_end = drug_groups.last()
#tumor_change = (tumor_start - tumor_end)
#tumor_percent = (tumor_change/tumor_start)*100

# Preview data to confirm
tumor_end
# Out:
#           Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# Drug
# Capomulin     j246         35           38.753265                 1
# Ceftamin      x226          0           45.000000                 0
# Infubinol     a685         45           66.083066                 3
# Ketapril      h428          0           45.000000                 0
# Naftisol      f993         20           52.079510                 1
# Placebo       j235         20           52.942902                 1
# Propriva      n630          5           46.099100                 0
# Ramicane      c458         30           38.342008                 2
# Stelasyn      s565         45           72.588964                 2
# Zoniferol     w140          5           47.717952                 0

# %%
# Out:
# Drug
# Capomulin   -19.475303
# Ceftamin     42.516492
# Infubinol    46.123472
# Ketapril     57.028795
# Naftisol     53.923347
# Placebo      51.297960
# Propriva     47.241175
# Ramicane    -22.320900
# Stelasyn     52.085134
# Zoniferol    46.579751
# dtype: float64

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
